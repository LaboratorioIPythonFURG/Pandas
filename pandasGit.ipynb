# %% [markdown]
# # Importar dados

# %%
import pandas as pd
uri = "https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula1.2/ratings.csv"
uri2 = "https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula4.1/movies.csv"
filmes = pd.read_csv(uri2)
notas = pd.read_csv(uri)
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
filmes.columns = ["filmeId", "titulo", "genero"]
filmes.columns
# Out:
# Index(['filmeId', 'titulo', 'genero'], dtype='object')

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "tempo"]
notas.head()
# Out:
#    usuarioId  filmeId  nota      tempo
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
notas.nota.hist()

# %%
mediadenotas = notas.groupby(by = "filmeId").mean()["nota"]


filmes.describe()
# Out:
#              filmeId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
mediadenotasporfilme = notas.groupby(by = "nota").count()

mediadenotasporfilme.plot()

# %%
filmes[filmes["movieId"] == 5]

n = notas.groupby(by = "filmeId").mean().reset_index()[["filmeId", "nota"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'movieId'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
novoDB = pd.merge(filmes, n)
novodb2 = novoDB.sort_values(by="nota", ascending=False)
novodb2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6264cd1e5f31> in <module>
# ----> 1 novoDB = pd.merge(filmes, n)
#       2 novodb2 = novoDB.sort_values(by="nota", ascending=False)
#       3 novodb2
#
# NameError: name 'n' is not defined

# %%
notas.nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(filmes['genero'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6ca5fc9490>,
# ...
#  [Text(1.0371875465263145, 0.36639049295898035, ''),
#   Text(0.6088764639603192, 0.9161165054921663, ''),
#   Text(0.15485439960096234, 1.0890455063606046, ''),
#   Text(-0.1274151166205857, 1.0925957111651878, ''),
#   Text(-0.37273853853784783, 1.0349231768052494, ''),
#   Text(-0.591337023758658, 0.9275346485885324, ''),
#   Text(-0.7624951860191189, 0.7928436739343194, ''),
#   Text(-0.8678251711832539, 0.6759285999724797, ''),
#   Text(-0.9356450550778349, 0.5784188196353879, ''),
#   Text(-0.9874539349219639, 0.4847006564954601, ''),
#   Text(-1.0257345268479983, 0.39732691883625665, ''),
#   Text(-1.0553058887619646, 0.3103699101786769, ''),
#   Text(-1.0760704089347397, 0.22819394167028736, ''),
#   Text(-1.0892937776723437, 0.1530982231259233, ''),
#   Text(-1.0967071501755705, 0.08504955469477017, ''),
#   Text(-1.0997657331031232, 0.02270093152604879, ''),
#   Text(-1.0994946544099111, -0.033339240003787914, ''),
# ...
