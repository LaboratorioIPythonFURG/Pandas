# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['figure.figsize'] = (16,8)

# %%
def consulta_bc(codigo_bcb):
  url = 'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
  df = pd.read_json(url)
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

# %%
desemprego = consulta_bc(24369)
plt.plot(desemprego)

# %%
ipca = consulta_bc(433)
igpm = consulta_bc(189)
selic = consulta_bc(432)

plt.plot(ipca, 'r', selic, 'b')

# %%
desempregorj = consulta_bc(1625)
desempregosp = consulta_bc(1626)

plt.plot(desempregorj, 'g', desempregosp, 'r')
